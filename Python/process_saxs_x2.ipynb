# %%
###########################################################################
#           Code to process SAXS output files to CSV files                #
#                       and calculate the X^2                             #
#                    Author: Renato D. Cunha, PhD                         #
#                     E-mail: renatodias@ub.edu                           #
#                          Version: 1.0                                   #
###########################################################################
#                                                                         #
# READ ME:                                                                #
# 1 - All the .abs files need to be in the same folder                    #
# 2 - The data is organized by default with ',' as separator              #
# 3 - Feel free to adapt the code to your needs                           #
#                                                                         #
###########################################################################

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
from scipy.optimize import minimize

# %%
def converter_arquivos_para_csv():
    # Obtém o diretório atual
    pasta_entrada = os.getcwd()

    # Verifica se o diretório de saída existe, senão cria
    pasta_saida = 'csv_output'
    os.makedirs(pasta_saida, exist_ok=True)

    # Lista todos os arquivos com extensão .abs no diretório de entrada
    arquivos_abs = [f for f in os.listdir(pasta_entrada) if f.endswith('.abs')]

    for arquivo_abs in arquivos_abs:
        # Constrói o caminho completo para o arquivo de entrada
        caminho_abs = os.path.join(pasta_entrada, arquivo_abs)

        # Lista para armazenar linhas processadas
        linhas_processadas = []

        # Flag para indicar se é a primeira linha
        primeira_linha = True

        # Lê o arquivo .abs linha a linha
        with open(caminho_abs, 'r') as file:
            for linha in file:
                # Pula a primeira linha que contém os títulos das colunas
                if primeira_linha:
                    primeira_linha = False
                    continue

                # Extrai os valores manualmente com base na posição
                valor1 = float(linha[:21].replace('D', 'E').strip())  # Substitui 'D' por 'E' na notação científica
                valor2 = float(linha[21:42].replace('D', 'E').strip())  # Substitui 'D' por 'E' na notação científica

                # Adiciona os valores processados à lista
                linhas_processadas.append([valor1, valor2])

        # Converte a lista de linhas processadas para DataFrame
        dados = pd.DataFrame(linhas_processadas, columns=['Coluna1', 'Coluna2'])

        # Constrói o caminho completo para o arquivo de saída (CSV)
        caminho_csv = os.path.join(pasta_saida, f"{os.path.splitext(arquivo_abs)[0]}.csv")

        # Salva os dados no formato CSV com vírgula como separador
        dados.to_csv(caminho_csv, index=False, sep=',')

        print(f"Conversão concluída para {caminho_csv}")

# %%
def calcular_media_colunas_csv():
    # Obtém o diretório atual
    pasta_trabalho = os.path.join(os.getcwd(), 'csv_output')

    # Lista todos os arquivos com extensão .csv na pasta "csv_output"
    arquivos_csv = [f for f in os.listdir(pasta_trabalho) if f.endswith('.csv')]

    # Lista para armazenar os DataFrames de cada arquivo
    dfs = []

    # Loop sobre os arquivos CSV
    for arquivo_csv in arquivos_csv:
        # Constrói o caminho completo para o arquivo CSV
        caminho_csv = os.path.join(pasta_trabalho, arquivo_csv)

        # Lê os dados do arquivo CSV
        dados = pd.read_csv(caminho_csv, index_col=0)  # Assumindo que a primeira coluna é o índice

        # Adiciona o DataFrame à lista
        dfs.append(dados)

        # Print para mostrar o arquivo que está sendo usado
        print(f"Usando arquivo: {arquivo_csv}")

    # Calcula a média final para todas as colunas através dos arquivos
    media_final_colunas = pd.concat(dfs, axis=1).mean(axis=1)

    # Cria um DataFrame com a média final das colunas
    df_resultado = pd.DataFrame({'Média Colunas': media_final_colunas})

    # Print para visualizar o DataFrame
    print("\nDataFrame Resultado:")
    print(df_resultado)

    # Salva o DataFrame no arquivo Resultado_Medias.csv
    caminho_saida = os.path.join(pasta_trabalho, 'SAXS_avg.csv')
    df_resultado.to_csv(caminho_saida)

# %%
def processar_e_escalar_saxs_avg():
    # Obtém o diretório atual
    pasta_trabalho = os.getcwd()

    # Caminho completo para o arquivo SAXS_avg.csv na pasta "csv_output"
    caminho_saxs_avg = os.path.join(pasta_trabalho, 'csv_output', 'SAXS_avg.csv')

    # Verifica se o arquivo SAXS_avg.csv existe
    if os.path.exists(caminho_saxs_avg):
        # Carrega o DataFrame do arquivo SAXS_avg.csv
        df_saxs_avg = pd.read_csv(caminho_saxs_avg)

        # Escala os valores da coluna 1 por 10 e da coluna 2 divide por 3
        df_saxs_avg.iloc[:, 0] *= 10
        df_saxs_avg.iloc[:, 1] /= 2.206

        # Salva o DataFrame no novo arquivo SAXS_avg_processado.csv
        caminho_novo_saxs_avg = os.path.join(pasta_trabalho, 'SAXS_avg_processado.csv')
        df_saxs_avg.to_csv(caminho_novo_saxs_avg, index=False, header=['q_theo', 'I_theo'])

        # Print para verificar o DataFrame processado
        print("\nDataFrame Processado:")
        print(df_saxs_avg)

        print(f"\nNovo arquivo SAXS_avg_processado.csv salvo em: {caminho_novo_saxs_avg}")
    else:
        print("O arquivo SAXS_avg.csv não foi encontrado na pasta 'csv_output'.")

# %%
def interpolar_e_salvar_saxs_theo(arquivo_exp, arquivo_avg_processado):
    # Carregar os dois arquivos, ignorando a primeira linha
    df_exp = pd.read_csv(arquivo_exp, skiprows=1)
    df_avg_processado = pd.read_csv(arquivo_avg_processado, skiprows=1)

    # Extrair valores de x e y dos DataFrames
    x_exp, y_exp = df_exp.iloc[:, 0], df_exp.iloc[:, 1]
    x_avg_processado, y_avg_processado = df_avg_processado.iloc[:, 0], df_avg_processado.iloc[:, 1]

    # Interpolar os valores de y_avg_processado para os pontos de x_exp
    interpolador = interp1d(x_avg_processado, y_avg_processado, kind='linear', fill_value='extrapolate')
    y_theo_interpolado = interpolador(x_exp)

    # Criar DataFrame com os valores interpolados
    df_theo_interpolado = pd.DataFrame({'q_theo': x_exp, 'I_theo_interpolado': y_theo_interpolado})

    # Salvar o DataFrame no arquivo SAXS_theo.csv
    caminho_saxs_theo = os.path.join(os.getcwd(), 'SAXS_theo.csv')
    df_theo_interpolado.to_csv(caminho_saxs_theo, index=False)

    print(f"\nArquivo SAXS_theo.csv salvo com os valores interpolados.")

# %%
def calcular_x2_e_salvar(arquivo_exp, arquivo_theo):
    # Carregar os dois arquivos, ignorando a primeira linha
    df_exp = pd.read_csv(arquivo_exp, skiprows=1)
    df_theo = pd.read_csv(arquivo_theo, skiprows=1)

    # Garantir que ambos os DataFrames tenham o mesmo número de linhas
    min_linhas = min(df_exp.shape[0], df_theo.shape[0])
    df_exp = df_exp.head(min_linhas)
    df_theo = df_theo.head(min_linhas)

    # Garantir que SAXS_theo.csv tenha 2 colunas e SAXS_exp_fixed.csv tenha 3 colunas
    df_theo = df_theo.iloc[:, :2]
    df_exp = df_exp.iloc[:, :3]

    # Double-check: garantir que a primeira coluna dos dois arquivos seja igual
    if not df_exp.iloc[:, 0].equals(df_theo.iloc[:, 0]):
        raise ValueError("As primeiras colunas dos arquivos não são iguais.")

    # Atribuir variáveis para facilitar o cálculo
    I_theo = df_theo.iloc[:, 1]
    I_exp = df_exp.iloc[:, 1]
    I_error = df_exp.iloc[:, 2]

    # Calcular x_2 para todos os pontos
    x_2 = (((I_exp - (0.682103 * I_theo + 0.000009) / I_error) ** 2

    # Criar DataFrame com os valores calculados
    df_x2_calc = pd.DataFrame({'q_exp': df_exp.iloc[:, 0], 'x_2': x_2})

    # Salvar o DataFrame no arquivo x2_calc.csv
    caminho_x2_calc = os.path.join(os.getcwd(), 'x2_calc.csv')
    df_x2_calc.to_csv(caminho_x2_calc, index=False)

    # Printar os valores de x_2
    print("\nValores de x_2 para cada ponto:")
    print(df_x2_calc)

    # Calcular e printar a média de todos os x_2 calculados
    media_x2 = x_2.sum() / 180
    print(f"\nMédia de x_2: {media_x2}")

    print(f"\nArquivo x2_calc.csv salvo com os valores de x_2.")
# Out:
#   File "<ipython-input-6-685755435811>", line 28
#     df_x2_calc = pd.DataFrame({'q_exp': df_exp.iloc[:, 0], 'x_2': x_2})
#     ^
# SyntaxError: invalid syntax

# %%
def calcular_x2_e_salvar_otimizado(arquivo_exp, arquivo_theo):
    # Carregar os dois arquivos, ignorando a primeira linha
    df_exp = pd.read_csv(arquivo_exp, skiprows=1)
    df_theo = pd.read_csv(arquivo_theo, skiprows=1)

    # Garantir que ambos os DataFrames tenham o mesmo número de linhas
    min_linhas = min(df_exp.shape[0], df_theo.shape[0])
    df_exp = df_exp.head(min_linhas)
    df_theo = df_theo.head(min_linhas)

    # Garantir que SAXS_theo.csv tenha 2 colunas e SAXS_exp_fixed.csv tenha 3 colunas
    df_theo = df_theo.iloc[:, :2]
    df_exp = df_exp.iloc[:, :3]

    # Double-check: garantir que a primeira coluna dos dois arquivos seja igual
    if not df_exp.iloc[:, 0].equals(df_theo.iloc[:, 0]):
        raise ValueError("As primeiras colunas dos arquivos não são iguais.")

    # Atribuir variáveis para facilitar o cálculo
    q_exp = df_exp.iloc[:, 0]
    I_theo = df_theo.iloc[:, 1]
    I_exp = df_exp.iloc[:, 1]
    I_error = df_exp.iloc[:, 2]

    # Função objetivo para minimizar
    def objetivo(params):
        c, b = params
        x_2 = ((I_exp - (c * I_theo + b))/ I_error) ** 2
        return x_2.sum()
                
    # Valor inicial para c e b
    parametros_iniciais = [1.0, 1.0]

    # Otimização
    resultado_otimizacao = minimize(objetivo, parametros_iniciais, method='BFGS')

    # Parâmetros otimizados
    c_otimizado, b_otimizado = resultado_otimizacao.x

    print(f"\nParâmetros otimizados: c = {c_otimizado:.4f}, b = {b_otimizado:.4f}")

    # Calcular x_2 para todos os pontos usando os parâmetros otimizados
    x_2_otimizado = (((I_exp - ((c_otimizado * I_theo) + b_otimizado))) / I_error) ** 2

    # Criar DataFrame com os valores calculados e os parâmetros otimizados
    df_x2_calc = pd.DataFrame({'q_exp': q_exp, 'x_2': x_2_otimizado, 'c_otimizado': c_otimizado, 'b_otimizado': b_otimizado})

    # Salvar o DataFrame no arquivo x2_calc.csv
    caminho_x2_calc = os.path.join(os.getcwd(), 'x2_calc.csv')
    df_x2_calc.to_csv(caminho_x2_calc, index=False)

    # Printar os valores de x_2 otimizado e os parâmetros otimizados
    print("\nValores de x_2 otimizado para cada ponto e parâmetros otimizados:")
    print(df_x2_calc)

    # Calcular e printar a média de todos os x_2 otimizados
    media_x2_otimizado = x_2_otimizado.mean()
    
    print(f"\nMédia de x_2 otimizado: {media_x2_otimizado}")

    print(f"\nArquivo x2_calc.csv salvo com os valores de x_2 otimizado e parâmetros otimizados.")

# %%
# Exemplo de uso
converter_arquivos_para_csv()
calcular_media_colunas_csv()
processar_e_escalar_saxs_avg()
interpolar_e_salvar_saxs_theo('SAXS_exp.csv', 'SAXS_avg_processado.csv')
#calcular_x2_e_salvar_otimizado('SAXS_exp_fixed.csv', 'SAXS_theo.csv')
#calcular_x2_e_salvar('SAXS_exp_fixed.csv', 'SAXS_theo.csv')
# Out:
# Conversão concluída para csv_output/SIRAH_c08_nowat_1289.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1357.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1123.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_951.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_381.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1007.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1223.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_39.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_316.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_319.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1106.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_93.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_276.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1452.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_863.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_782.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1483.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_554.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_220.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1162.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1184.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1166.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_512.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_325.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_819.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_704.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_56.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_864.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_341.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_192.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_244.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1363.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_477.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1043.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_471.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1435.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1256.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1239.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_357.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_728.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_379.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1208.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1460.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1179.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_358.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1258.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1120.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1330.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1443.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1181.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1037.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_819.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_814.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_602.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1140.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1060.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1176.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_139.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_964.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_594.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_421.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_298.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1091.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_211.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1043.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_536.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1462.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_550.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1266.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_968.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_269.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_697.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_299.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1281.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1093.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1446.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1465.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_908.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_458.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1161.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1413.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_966.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1497.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_301.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_589.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1321.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1067.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_488.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_886.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_268.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1424.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_729.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1265.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_679.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_707.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1320.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_19.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_840.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_653.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1485.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1029.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_558.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_227.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1097.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_496.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1157.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_185.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_897.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_305.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_469.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_350.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_527.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_333.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_348.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_23.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1058.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_862.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_21.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_732.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1220.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1307.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_294.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1282.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_277.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_441.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_290.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_547.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1071.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_86.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_144.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1243.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_497.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_288.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_850.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_293.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1267.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1313.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_987.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_643.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_427.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_616.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_911.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_868.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_56.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_878.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_161.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_662.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_906.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_810.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_96.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_610.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_597.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_937.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_82.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1384.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_604.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1315.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_773.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_803.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_942.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_400.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1087.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_633.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_738.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1114.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_782.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_977.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1286.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_208.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_994.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1452.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_67.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_307.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_385.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1308.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_955.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1019.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1496.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_306.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_238.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_484.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_910.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_752.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1079.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_515.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_994.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1395.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_35.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1292.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_930.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_921.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_526.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1274.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_30.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_706.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_722.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_11.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_504.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_90.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_302.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_122.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1242.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_300.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1487.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1099.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1190.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_755.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1292.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1100.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1224.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_486.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_145.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_208.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1278.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1084.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1122.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1459.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_920.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_557.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_972.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1413.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1148.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_991.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1194.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1335.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_483.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_520.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_871.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_644.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1326.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_762.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_591.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_954.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1045.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1088.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_390.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1301.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_532.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_452.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1064.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_450.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_363.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1024.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1308.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_604.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1213.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_310.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_676.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_194.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1196.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_218.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_590.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_875.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_487.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_386.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_684.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1249.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1302.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_373.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_701.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_583.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1179.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_96.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_664.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_835.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1366.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_226.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_192.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1467.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_407.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_844.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_981.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_639.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_212.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_494.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_57.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1154.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_420.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1379.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_947.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_534.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_744.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_751.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_534.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1300.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1189.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_27.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_967.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1325.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1362.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1030.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1098.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_87.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1138.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1107.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_360.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1353.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_798.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1484.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_881.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1463.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1294.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1450.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_559.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_521.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_50.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_114.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1419.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_65.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1028.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1196.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1476.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1035.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_435.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_797.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1308.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_645.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_310.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_116.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_385.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_479.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_146.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_492.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_491.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1152.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_562.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_136.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_88.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_592.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1396.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_747.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_121.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_542.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1483.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_248.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_502.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1332.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_492.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_381.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1227.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_630.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1089.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_960.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_532.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1473.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_341.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1417.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_676.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1416.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1291.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_89.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_491.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_243.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1481.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1406.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1210.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_534.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_590.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1396.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1391.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_237.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_769.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_614.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_383.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_32.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_42.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1301.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_576.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_682.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1298.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_7.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_127.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_331.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_140.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_532.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_677.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_250.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1444.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1351.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1088.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_870.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_870.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1056.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_226.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_356.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_872.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_748.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1146.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_161.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_921.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1117.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_92.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1319.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1442.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1199.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1360.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_776.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1410.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1254.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1282.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1248.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_542.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_725.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_615.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1174.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_104.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_203.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_616.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_446.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1076.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_198.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_465.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1315.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_457.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1051.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_985.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1082.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_495.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1318.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_627.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_368.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_159.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1246.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_932.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_581.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_565.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1142.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_698.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_941.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_933.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_87.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1234.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_106.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_608.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_418.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1401.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1354.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_367.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1375.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_975.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_92.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1372.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_270.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_99.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_435.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1402.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_711.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1156.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1110.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1068.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_775.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_193.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1339.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_815.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_515.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_437.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_574.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_778.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_597.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_903.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_445.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_308.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_312.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1358.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1012.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_705.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_778.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1092.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_124.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_337.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1271.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1357.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1170.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1443.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_255.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1301.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1160.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1333.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1497.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1145.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_786.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1280.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_866.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_723.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_47.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1426.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1030.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1127.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_590.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_800.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_233.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_406.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_449.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_353.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_279.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_317.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_766.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1498.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_562.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_755.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_849.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_871.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_752.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_41.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_940.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_97.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_232.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_498.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_481.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_700.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1412.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1405.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_425.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_820.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_446.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_852.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_810.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_261.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1478.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1345.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1354.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_949.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_383.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_979.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_506.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_725.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1010.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_996.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_971.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_655.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_162.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1427.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_759.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_306.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_665.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_431.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_855.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1138.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_836.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_596.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_411.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1150.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_785.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_627.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_791.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_443.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1338.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1475.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_61.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_714.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_846.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_521.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_684.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1241.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1143.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1168.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_741.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1485.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_979.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_635.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1270.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1258.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_929.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_595.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_389.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_270.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_853.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_385.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_647.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_310.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_847.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1287.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1284.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_695.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_575.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_444.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_396.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_462.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_753.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_740.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1331.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_817.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_572.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1083.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_594.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_598.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_758.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_188.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_599.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1274.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1178.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_739.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_150.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_913.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1471.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_575.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_38.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_729.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_387.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_90.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_762.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_477.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1390.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1269.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_386.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1174.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1211.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_101.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1025.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_575.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1047.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1212.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_933.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_585.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_377.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1341.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_350.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1179.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1320.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1142.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_677.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_593.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_117.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_19.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1379.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1025.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_633.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_330.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_251.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_140.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_665.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1321.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_556.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_571.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1457.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1392.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1240.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1144.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1081.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1389.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_232.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1113.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_988.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_760.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_889.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_750.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_845.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1441.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1495.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_799.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_371.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1127.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_768.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1136.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1385.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1051.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1476.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_436.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_207.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_596.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_919.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_113.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1477.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_5.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_497.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1091.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_243.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_210.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_413.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_451.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_989.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_966.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_9.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_540.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1048.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1191.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1277.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_493.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1360.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1211.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_898.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_4.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1262.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_314.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_713.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1049.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_608.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_9.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_754.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1063.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_857.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_580.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_606.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_84.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_807.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_984.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_896.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_228.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_420.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_615.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1192.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_879.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_170.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1328.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1202.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_382.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_865.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1184.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1030.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1169.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1272.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1008.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1152.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_633.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_506.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_120.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_980.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1178.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_985.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_519.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_611.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_115.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1335.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_607.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_189.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_453.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_741.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_457.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1269.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1145.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1375.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1465.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1353.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1122.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_358.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_90.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_847.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_622.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_818.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_539.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_378.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_356.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_814.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1015.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1391.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_660.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1319.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1193.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_59.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1125.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_686.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_295.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1343.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1002.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1358.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_434.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_781.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1404.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_77.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1194.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_746.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1494.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_179.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1201.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1366.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1385.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1251.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_978.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1382.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1366.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1330.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_425.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1082.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1137.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_657.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1109.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1392.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_839.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1230.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_281.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_450.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_335.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_219.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1168.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_772.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1289.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_1126.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_999.csv
# Conversão concluída para csv_output/SIRAH_c08_nowat_302.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_278.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_913.csv
# Conversão concluída para csv_output/SIRAH_c06_nowat_1083.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_1032.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_67.csv
# Conversão concluída para csv_output/SIRAH_c04_nowat_917.csv
# ...
# Usando arquivo: GaMD_c08_nowat_158.csv
# Usando arquivo: GaMD_c08_nowat_227.csv
# Usando arquivo: GaMD_c08_nowat_95.csv
# Usando arquivo: GaMD_c08_nowat_98.csv
# Usando arquivo: GaMD_c08_nowat_174.csv
# Usando arquivo: GaMD_c08_nowat_432.csv
# Usando arquivo: GaMD_c08_nowat_421.csv
# Usando arquivo: GaMD_c08_nowat_310.csv
# Usando arquivo: SAXS_avg.csv
# Usando arquivo: GaMD_c08_nowat_463.csv
# Usando arquivo: GaMD_c08_nowat_336.csv
# Usando arquivo: GaMD_c08_nowat_14.csv
# Usando arquivo: GaMD_c08_nowat_272.csv
# Usando arquivo: GaMD_c08_nowat_283.csv
# Usando arquivo: GaMD_c08_nowat_265.csv
# Usando arquivo: GaMD_c08_nowat_163.csv
# Usando arquivo: GaMD_c08_nowat_23.csv
# Usando arquivo: GaMD_c08_nowat_429.csv
# Usando arquivo: GaMD_c08_nowat_233.csv
# Usando arquivo: GaMD_c08_nowat_287.csv
# Usando arquivo: GaMD_c08_nowat_237.csv
# Usando arquivo: GaMD_c08_nowat_456.csv
# Usando arquivo: GaMD_c08_nowat_494.csv
# Usando arquivo: GaMD_c08_nowat_312.csv
# Usando arquivo: GaMD_c08_nowat_156.csv
# Usando arquivo: GaMD_c08_nowat_261.csv
# Usando arquivo: GaMD_c08_nowat_289.csv
# Usando arquivo: GaMD_c08_nowat_147.csv
# Usando arquivo: GaMD_c08_nowat_129.csv
# Usando arquivo: GaMD_c08_nowat_38.csv
# Usando arquivo: GaMD_c08_nowat_164.csv
# Usando arquivo: GaMD_c08_nowat_311.csv
# Usando arquivo: GaMD_c08_nowat_260.csv
# Usando arquivo: GaMD_c08_nowat_202.csv
# Usando arquivo: GaMD_c08_nowat_479.csv
# Usando arquivo: GaMD_c08_nowat_396.csv
# Usando arquivo: GaMD_c08_nowat_335.csv
# Usando arquivo: GaMD_c08_nowat_256.csv
# Usando arquivo: GaMD_c08_nowat_397.csv
# Usando arquivo: GaMD_c08_nowat_116.csv
# Usando arquivo: GaMD_c08_nowat_89.csv
# Usando arquivo: GaMD_c08_nowat_354.csv
# Usando arquivo: GaMD_c08_nowat_436.csv
# Usando arquivo: GaMD_c08_nowat_127.csv
# Usando arquivo: GaMD_c08_nowat_248.csv
# Usando arquivo: GaMD_c08_nowat_107.csv
# Usando arquivo: GaMD_c08_nowat_373.csv
# Usando arquivo: GaMD_c08_nowat_239.csv
# Usando arquivo: GaMD_c08_nowat_485.csv
# Usando arquivo: GaMD_c08_nowat_433.csv
# Usando arquivo: GaMD_c08_nowat_370.csv
# Usando arquivo: GaMD_c08_nowat_221.csv
# Usando arquivo: GaMD_c08_nowat_91.csv
# Usando arquivo: GaMD_c08_nowat_399.csv
# Usando arquivo: GaMD_c08_nowat_352.csv
# Usando arquivo: GaMD_c08_nowat_369.csv
# Usando arquivo: GaMD_c08_nowat_376.csv
# Usando arquivo: GaMD_c08_nowat_90.csv
# Usando arquivo: GaMD_c08_nowat_181.csv
# Usando arquivo: GaMD_c08_nowat_329.csv
# Usando arquivo: GaMD_c08_nowat_175.csv
# Usando arquivo: GaMD_c08_nowat_134.csv
# Usando arquivo: GaMD_c08_nowat_130.csv
# Usando arquivo: GaMD_c08_nowat_438.csv
# Usando arquivo: GaMD_c08_nowat_497.csv
# Usando arquivo: GaMD_c08_nowat_35.csv
# Usando arquivo: GaMD_c08_nowat_470.csv
# Usando arquivo: GaMD_c08_nowat_453.csv
# Usando arquivo: GaMD_c08_nowat_387.csv
# Usando arquivo: GaMD_c08_nowat_140.csv
# Usando arquivo: GaMD_c08_nowat_30.csv
# Usando arquivo: GaMD_c08_nowat_229.csv
# Usando arquivo: GaMD_c08_nowat_455.csv
# Usando arquivo: GaMD_c08_nowat_71.csv
# Usando arquivo: GaMD_c08_nowat_108.csv
# Usando arquivo: GaMD_c08_nowat_488.csv
# Usando arquivo: GaMD_c08_nowat_257.csv
# Usando arquivo: GaMD_c08_nowat_112.csv
# Usando arquivo: GaMD_c08_nowat_50.csv
# Usando arquivo: GaMD_c08_nowat_59.csv
# Usando arquivo: GaMD_c08_nowat_169.csv
# Usando arquivo: GaMD_c08_nowat_357.csv
# Usando arquivo: GaMD_c08_nowat_52.csv
# Usando arquivo: GaMD_c08_nowat_177.csv
# Usando arquivo: GaMD_c08_nowat_17.csv
# Usando arquivo: GaMD_c08_nowat_120.csv
# Usando arquivo: GaMD_c08_nowat_113.csv
# Usando arquivo: GaMD_c08_nowat_338.csv
# Usando arquivo: GaMD_c08_nowat_493.csv
# Usando arquivo: GaMD_c08_nowat_74.csv
# Usando arquivo: GaMD_c08_nowat_209.csv
# Usando arquivo: GaMD_c08_nowat_319.csv
# Usando arquivo: GaMD_c08_nowat_238.csv
# Usando arquivo: GaMD_c08_nowat_316.csv
# Usando arquivo: GaMD_c08_nowat_345.csv
# Usando arquivo: GaMD_c08_nowat_185.csv
# Usando arquivo: GaMD_c08_nowat_341.csv
# Usando arquivo: GaMD_c08_nowat_106.csv
# Usando arquivo: GaMD_c08_nowat_128.csv
# Usando arquivo: GaMD_c08_nowat_97.csv
# Usando arquivo: GaMD_c08_nowat_102.csv
# Usando arquivo: GaMD_c08_nowat_391.csv
# Usando arquivo: GaMD_c08_nowat_388.csv
# Usando arquivo: GaMD_c08_nowat_350.csv
# Usando arquivo: GaMD_c08_nowat_480.csv
# Usando arquivo: GaMD_c08_nowat_327.csv
# Usando arquivo: GaMD_c08_nowat_278.csv
# Usando arquivo: GaMD_c08_nowat_39.csv
# Usando arquivo: GaMD_c08_nowat_413.csv
# Usando arquivo: GaMD_c08_nowat_296.csv
# Usando arquivo: GaMD_c08_nowat_9.csv
# Usando arquivo: GaMD_c08_nowat_76.csv
# Usando arquivo: GaMD_c08_nowat_236.csv
# Usando arquivo: GaMD_c08_nowat_334.csv
# Usando arquivo: GaMD_c08_nowat_266.csv
# Usando arquivo: GaMD_c08_nowat_123.csv
# Usando arquivo: GaMD_c08_nowat_78.csv
# Usando arquivo: GaMD_c08_nowat_364.csv
# Usando arquivo: GaMD_c08_nowat_496.csv
# Usando arquivo: GaMD_c08_nowat_439.csv
# Usando arquivo: GaMD_c08_nowat_242.csv
# Usando arquivo: GaMD_c08_nowat_13.csv
# Usando arquivo: GaMD_c08_nowat_46.csv
# Usando arquivo: GaMD_c08_nowat_4.csv
# Usando arquivo: GaMD_c08_nowat_199.csv
# Usando arquivo: GaMD_c08_nowat_228.csv
# Usando arquivo: GaMD_c08_nowat_172.csv
# Usando arquivo: GaMD_c08_nowat_58.csv
# Usando arquivo: GaMD_c08_nowat_157.csv
# Usando arquivo: GaMD_c08_nowat_359.csv
# Usando arquivo: GaMD_c08_nowat_11.csv
# Usando arquivo: GaMD_c08_nowat_186.csv
# Usando arquivo: GaMD_c08_nowat_410.csv
# Usando arquivo: GaMD_c08_nowat_483.csv
# Usando arquivo: GaMD_c08_nowat_426.csv
# Usando arquivo: GaMD_c08_nowat_267.csv
# Usando arquivo: GaMD_c08_nowat_282.csv
# Usando arquivo: GaMD_c08_nowat_8.csv
# Usando arquivo: GaMD_c08_nowat_69.csv
# Usando arquivo: GaMD_c08_nowat_323.csv
# Usando arquivo: GaMD_c08_nowat_250.csv
# Usando arquivo: GaMD_c08_nowat_85.csv
# Usando arquivo: GaMD_c08_nowat_409.csv
# Usando arquivo: GaMD_c08_nowat_472.csv
# Usando arquivo: GaMD_c08_nowat_93.csv
# Usando arquivo: GaMD_c08_nowat_389.csv
# Usando arquivo: GaMD_c08_nowat_159.csv
# Usando arquivo: GaMD_c08_nowat_125.csv
# Usando arquivo: GaMD_c08_nowat_340.csv
# Usando arquivo: GaMD_c08_nowat_148.csv
# Usando arquivo: GaMD_c08_nowat_403.csv
# Usando arquivo: GaMD_c08_nowat_362.csv
# Usando arquivo: GaMD_c08_nowat_208.csv
# Usando arquivo: GaMD_c08_nowat_246.csv
# Usando arquivo: GaMD_c08_nowat_15.csv
# Usando arquivo: GaMD_c08_nowat_132.csv
# Usando arquivo: GaMD_c08_nowat_193.csv
# Usando arquivo: GaMD_c08_nowat_277.csv
# Usando arquivo: GaMD_c08_nowat_203.csv
# Usando arquivo: GaMD_c08_nowat_365.csv
# Usando arquivo: GaMD_c08_nowat_200.csv
# Usando arquivo: GaMD_c08_nowat_447.csv
# Usando arquivo: GaMD_c08_nowat_191.csv
# Usando arquivo: GaMD_c08_nowat_489.csv
# Usando arquivo: GaMD_c08_nowat_53.csv
# Usando arquivo: GaMD_c08_nowat_94.csv
# Usando arquivo: GaMD_c08_nowat_366.csv
# Usando arquivo: GaMD_c08_nowat_349.csv
# Usando arquivo: GaMD_c08_nowat_368.csv
# Usando arquivo: GaMD_c08_nowat_430.csv
# Usando arquivo: GaMD_c08_nowat_275.csv
# Usando arquivo: GaMD_c08_nowat_79.csv
# Usando arquivo: GaMD_c08_nowat_290.csv
# Usando arquivo: GaMD_c08_nowat_384.csv
# Usando arquivo: GaMD_c08_nowat_280.csv
# Usando arquivo: GaMD_c08_nowat_400.csv
# Usando arquivo: GaMD_c08_nowat_82.csv
# Usando arquivo: GaMD_c08_nowat_499.csv
# Usando arquivo: GaMD_c08_nowat_301.csv
# Usando arquivo: GaMD_c08_nowat_353.csv
# Usando arquivo: GaMD_c08_nowat_442.csv
# Usando arquivo: GaMD_c08_nowat_347.csv
# Usando arquivo: GaMD_c08_nowat_474.csv
# Usando arquivo: GaMD_c08_nowat_57.csv
# Usando arquivo: GaMD_c08_nowat_269.csv
# Usando arquivo: GaMD_c08_nowat_72.csv
# Usando arquivo: GaMD_c08_nowat_166.csv
# Usando arquivo: GaMD_c08_nowat_390.csv
# Usando arquivo: GaMD_c08_nowat_171.csv
# Usando arquivo: GaMD_c08_nowat_109.csv
# Usando arquivo: GaMD_c08_nowat_43.csv
# Usando arquivo: GaMD_c08_nowat_276.csv
# Usando arquivo: GaMD_c08_nowat_360.csv
# Usando arquivo: GaMD_c08_nowat_24.csv
# Usando arquivo: GaMD_c08_nowat_492.csv
# Usando arquivo: GaMD_c08_nowat_263.csv
# Usando arquivo: GaMD_c08_nowat_444.csv
# Usando arquivo: GaMD_c08_nowat_377.csv
# Usando arquivo: GaMD_c08_nowat_180.csv
# Usando arquivo: GaMD_c08_nowat_363.csv
# Usando arquivo: GaMD_c08_nowat_446.csv
# Usando arquivo: GaMD_c08_nowat_473.csv
# Usando arquivo: GaMD_c08_nowat_214.csv
# Usando arquivo: GaMD_c08_nowat_471.csv
# Usando arquivo: GaMD_c08_nowat_459.csv
# Usando arquivo: GaMD_c08_nowat_88.csv
# Usando arquivo: GaMD_c08_nowat_150.csv
# Usando arquivo: GaMD_c08_nowat_194.csv
# Usando arquivo: GaMD_c08_nowat_322.csv
# Usando arquivo: GaMD_c08_nowat_196.csv
# Usando arquivo: GaMD_c08_nowat_468.csv
# Usando arquivo: GaMD_c08_nowat_262.csv
# Usando arquivo: GaMD_c08_nowat_20.csv
# Usando arquivo: GaMD_c08_nowat_490.csv
# Usando arquivo: GaMD_c08_nowat_36.csv
# Usando arquivo: GaMD_c08_nowat_188.csv
# Usando arquivo: GaMD_c08_nowat_207.csv
# Usando arquivo: GaMD_c08_nowat_100.csv
# Usando arquivo: GaMD_c08_nowat_25.csv
# Usando arquivo: GaMD_c08_nowat_425.csv
# Usando arquivo: GaMD_c08_nowat_173.csv
# Usando arquivo: GaMD_c08_nowat_385.csv
# Usando arquivo: GaMD_c08_nowat_190.csv
# Usando arquivo: GaMD_c08_nowat_431.csv
# Usando arquivo: GaMD_c08_nowat_344.csv
# Usando arquivo: GaMD_c08_nowat_42.csv
# Usando arquivo: GaMD_c08_nowat_135.csv
# Usando arquivo: GaMD_c08_nowat_139.csv
# Usando arquivo: GaMD_c08_nowat_419.csv
# Usando arquivo: GaMD_c08_nowat_65.csv
# Usando arquivo: GaMD_c08_nowat_466.csv
# Usando arquivo: GaMD_c08_nowat_378.csv
# Usando arquivo: GaMD_c08_nowat_115.csv
# Usando arquivo: GaMD_c08_nowat_415.csv
# Usando arquivo: GaMD_c08_nowat_424.csv
# Usando arquivo: GaMD_c08_nowat_60.csv
# Usando arquivo: GaMD_c08_nowat_434.csv
# Usando arquivo: GaMD_c08_nowat_398.csv
# Usando arquivo: GaMD_c08_nowat_348.csv
# Usando arquivo: GaMD_c08_nowat_162.csv
# Usando arquivo: GaMD_c08_nowat_6.csv
# Usando arquivo: GaMD_c08_nowat_411.csv
# Usando arquivo: GaMD_c08_nowat_176.csv
# Usando arquivo: GaMD_c08_nowat_288.csv
# Usando arquivo: GaMD_c08_nowat_80.csv
# Usando arquivo: GaMD_c08_nowat_198.csv
# Usando arquivo: GaMD_c08_nowat_477.csv
# Usando arquivo: GaMD_c08_nowat_270.csv
# Usando arquivo: GaMD_c08_nowat_342.csv
# Usando arquivo: GaMD_c08_nowat_118.csv
# Usando arquivo: GaMD_c08_nowat_210.csv
# Usando arquivo: GaMD_c08_nowat_271.csv
# Usando arquivo: GaMD_c08_nowat_55.csv
# Usando arquivo: GaMD_c08_nowat_153.csv
# Usando arquivo: GaMD_c08_nowat_54.csv
# Usando arquivo: GaMD_c08_nowat_383.csv
# Usando arquivo: GaMD_c08_nowat_358.csv
# Usando arquivo: GaMD_c08_nowat_326.csv
# Usando arquivo: GaMD_c08_nowat_304.csv
# Usando arquivo: GaMD_c08_nowat_281.csv
# Usando arquivo: GaMD_c08_nowat_441.csv
# Usando arquivo: GaMD_c08_nowat_83.csv
# Usando arquivo: GaMD_c08_nowat_45.csv
# Usando arquivo: GaMD_c08_nowat_1.csv
# Usando arquivo: GaMD_c08_nowat_152.csv
# Usando arquivo: GaMD_c08_nowat_51.csv
# Usando arquivo: GaMD_c08_nowat_268.csv
# Usando arquivo: GaMD_c08_nowat_119.csv
# Usando arquivo: GaMD_c08_nowat_451.csv
# Usando arquivo: GaMD_c08_nowat_247.csv
# Usando arquivo: GaMD_c08_nowat_254.csv
# Usando arquivo: GaMD_c08_nowat_443.csv
# Usando arquivo: GaMD_c08_nowat_361.csv
# Usando arquivo: GaMD_c08_nowat_460.csv
# Usando arquivo: GaMD_c08_nowat_230.csv
# Usando arquivo: GaMD_c08_nowat_284.csv
# Usando arquivo: GaMD_c08_nowat_67.csv
# Usando arquivo: GaMD_c08_nowat_122.csv
# Usando arquivo: GaMD_c08_nowat_300.csv
# Usando arquivo: GaMD_c08_nowat_73.csv
# Usando arquivo: GaMD_c08_nowat_154.csv
# Usando arquivo: GaMD_c08_nowat_291.csv
# Usando arquivo: GaMD_c08_nowat_12.csv
# Usando arquivo: GaMD_c08_nowat_324.csv
# Usando arquivo: GaMD_c08_nowat_259.csv
# Usando arquivo: GaMD_c08_nowat_404.csv
# Usando arquivo: GaMD_c08_nowat_343.csv
# Usando arquivo: GaMD_c08_nowat_5.csv
# Usando arquivo: GaMD_c08_nowat_408.csv
# Usando arquivo: GaMD_c08_nowat_103.csv
# Usando arquivo: GaMD_c08_nowat_303.csv
# Usando arquivo: GaMD_c08_nowat_212.csv
# Usando arquivo: GaMD_c08_nowat_141.csv
# Usando arquivo: GaMD_c08_nowat_243.csv
# Usando arquivo: GaMD_c08_nowat_223.csv
# Usando arquivo: GaMD_c08_nowat_318.csv
# Usando arquivo: GaMD_c08_nowat_241.csv
# Usando arquivo: GaMD_c08_nowat_374.csv
# Usando arquivo: GaMD_c08_nowat_3.csv
# Usando arquivo: GaMD_c08_nowat_258.csv
# Usando arquivo: GaMD_c08_nowat_34.csv
# Usando arquivo: GaMD_c08_nowat_206.csv
# Usando arquivo: GaMD_c08_nowat_458.csv
# Usando arquivo: GaMD_c08_nowat_467.csv
# Usando arquivo: GaMD_c08_nowat_292.csv
# Usando arquivo: GaMD_c08_nowat_234.csv
# Usando arquivo: GaMD_c08_nowat_226.csv
# Usando arquivo: GaMD_c08_nowat_149.csv
# Usando arquivo: GaMD_c08_nowat_68.csv
# Usando arquivo: GaMD_c08_nowat_428.csv
# Usando arquivo: GaMD_c08_nowat_62.csv
# Usando arquivo: GaMD_c08_nowat_182.csv
# Usando arquivo: GaMD_c08_nowat_131.csv
# Usando arquivo: GaMD_c08_nowat_195.csv
# Usando arquivo: GaMD_c08_nowat_144.csv
# Usando arquivo: GaMD_c08_nowat_394.csv
# Usando arquivo: GaMD_c08_nowat_285.csv
# Usando arquivo: GaMD_c08_nowat_380.csv
# Usando arquivo: GaMD_c08_nowat_392.csv
# Usando arquivo: GaMD_c08_nowat_500.csv
# Usando arquivo: GaMD_c08_nowat_306.csv
# Usando arquivo: GaMD_c08_nowat_294.csv
# Usando arquivo: GaMD_c08_nowat_317.csv
# Usando arquivo: GaMD_c08_nowat_27.csv
# Usando arquivo: GaMD_c08_nowat_160.csv
# Usando arquivo: GaMD_c08_nowat_218.csv
# Usando arquivo: GaMD_c08_nowat_418.csv
# Usando arquivo: GaMD_c08_nowat_167.csv
# Usando arquivo: GaMD_c08_nowat_279.csv
# Usando arquivo: GaMD_c08_nowat_114.csv
# Usando arquivo: GaMD_c08_nowat_251.csv
# Usando arquivo: GaMD_c08_nowat_197.csv
# Usando arquivo: GaMD_c08_nowat_498.csv
# Usando arquivo: GaMD_c08_nowat_201.csv
# Usando arquivo: GaMD_c08_nowat_222.csv
# Usando arquivo: GaMD_c08_nowat_217.csv
# Usando arquivo: GaMD_c08_nowat_476.csv
# Usando arquivo: GaMD_c08_nowat_330.csv
# Usando arquivo: GaMD_c08_nowat_142.csv
# Usando arquivo: GaMD_c08_nowat_22.csv
# Usando arquivo: GaMD_c08_nowat_382.csv
# Usando arquivo: GaMD_c08_nowat_192.csv
# Usando arquivo: GaMD_c08_nowat_308.csv
# Usando arquivo: GaMD_c08_nowat_48.csv
# Usando arquivo: GaMD_c08_nowat_315.csv
# Usando arquivo: GaMD_c08_nowat_99.csv
# Usando arquivo: GaMD_c08_nowat_133.csv
# Usando arquivo: GaMD_c08_nowat_75.csv
# Usando arquivo: GaMD_c08_nowat_422.csv
# Usando arquivo: GaMD_c08_nowat_18.csv
# Usando arquivo: GaMD_c08_nowat_252.csv
# Usando arquivo: GaMD_c08_nowat_313.csv
# Usando arquivo: GaMD_c08_nowat_117.csv
# Usando arquivo: GaMD_c08_nowat_224.csv
# Usando arquivo: GaMD_c08_nowat_216.csv
# Usando arquivo: GaMD_c08_nowat_356.csv
# Usando arquivo: GaMD_c08_nowat_168.csv
# Usando arquivo: GaMD_c08_nowat_297.csv
# Usando arquivo: GaMD_c08_nowat_232.csv
# Usando arquivo: GaMD_c08_nowat_219.csv
# Usando arquivo: GaMD_c08_nowat_445.csv
# Usando arquivo: GaMD_c08_nowat_465.csv
# Usando arquivo: GaMD_c08_nowat_406.csv
# Usando arquivo: GaMD_c08_nowat_307.csv
# Usando arquivo: GaMD_c08_nowat_96.csv
#
# DataFrame Resultado:
#           Média Colunas
# Coluna1
# 0.000000       0.009057
# 0.002008       0.009032
# 0.004016       0.008958
# 0.006024       0.008836
# 0.008032       0.008669
# ...                 ...
# 0.491968       0.000102
# 0.493976       0.000101
# 0.495984       0.000100
# 0.497992       0.000099
# 0.500000       0.000098
#
# [250 rows x 1 columns]
#
# DataFrame Processado:
#       Coluna1  Média Colunas
# 0    0.000000       0.004105
# 1    0.020080       0.004094
# 2    0.040161       0.004061
# 3    0.060241       0.004005
# 4    0.080321       0.003930
# ..        ...            ...
# 245  4.919680       0.000046
# 246  4.939760       0.000046
# 247  4.959840       0.000045
# 248  4.979920       0.000045
# 249  5.000000       0.000045
#
# [250 rows x 2 columns]
#
# Novo arquivo SAXS_avg_processado.csv salvo em: /data2/rcunha/PHD/Sic1/GaMD/cluster_08/X_function_SAXS/SAXS_avg_processado.csv
#
# Arquivo SAXS_theo.csv salvo com os valores interpolados.
#
# Parâmetros otimizados: c = 1.1126, b = -0.0001
#
# Valores de x_2 otimizado para cada ponto e parâmetros otimizados:
#        q_exp         x_2  c_otimizado  b_otimizado
# 0    0.22193  173.787042     1.112558    -0.000057
# 1    0.23303  136.406389     1.112558    -0.000057
# 2    0.24413   82.906609     1.112558    -0.000057
# 3    0.25522  115.809904     1.112558    -0.000057
# 4    0.26632  166.926807     1.112558    -0.000057
# ..       ...         ...          ...          ...
# 175  2.16384    0.222897     1.112558    -0.000057
# 176  2.17494    0.023322     1.112558    -0.000057
# 177  2.18604    0.002498     1.112558    -0.000057
# 178  2.19713    0.189673     1.112558    -0.000057
# 179  2.20823    0.134404     1.112558    -0.000057
#
# [180 rows x 4 columns]
#
# Média de x_2 otimizado: 12.828859957307102
#
# Arquivo x2_calc.csv salvo com os valores de x_2 otimizado e parâmetros otimizados.
